# %% [markdown]
# <a href="https://colab.research.google.com/github/debarnabdas007/Learning-Pytorch/blob/main/02_PyTorch_Classification_video.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 02. Neural Network classification with PyTorch
#
# Classification is a problems of predicting whether something is one thing or another [ there can be multiple things as the options ]

# %% [markdown]
# ![02-different-classification-problems.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-04-13 100603.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-04-13 102022.png](data:image/png;base64,...)

# %% [markdown]
# ## Architecture of Classification Model

# %% [markdown]
# ![Screenshot 2026-04-13 111510.png](data:image/png;base64,...)

# %% [markdown]
# ## 1. Make classification data and get it ready

# %%
import sklearn

# %%
from sklearn.datasets import make_circles

# Make 1000 samples
n_samples = 1000

# Create circles
X, y = make_circles(n_samples,
                    noise=0.03,
                    random_state=42)

# %%
len(X), len(y)
# Out:
# (1000, 1000)

# %%
print(f"First 5 samples of X:\n {X[:5]}")
print(f"First 5 samples of y: {y[:5]}")
# Out:
# First 5 samples of X:
#  [[ 0.75424625  0.23148074]
#  [-0.75615888  0.15325888]
#  [-0.81539193  0.17328203]
#  [-0.39373073  0.69288277]
#  [ 0.44220765 -0.89672343]]
# First 5 samples of y: [1 1 1 1 0]

# %%
# Make Dataframe of Circle data

import pandas as pd
circles = pd.DataFrame({"X1" : X[:, 0],
                        "X2": X[:, 1],
                        "label" : y})

circles.head(10)
# Out:
#          X1        X2  label
# 0  0.754246  0.231481      1
# 1 -0.756159  0.153259      1
# 2 -0.815392  0.173282      1
# 3 -0.393731  0.692883      1
# 4  0.442208 -0.896723      0
# 5 -0.479646  0.676435      1
# 6 -0.013648  0.803349      1
# 7  0.771513  0.147760      1
# 8 -0.169322 -0.793456      1
# 9 -0.121486  1.021509      0

# %%
circles.label.value_counts()
# Out:
# label
# 1    500
# 0    500
# Name: count, dtype: int64

# %%
# Visualize
import matplotlib.pyplot as plt
plt.scatter(x=X[:, 0],
            y=X[:, 1],
            c=y,
            cmap=plt.cm.RdYlBu);

# %% [markdown]
# **Note**: The data we're working with is often referred to as a *toy dataset*, a dataset that is small enough to experiment but still sizeable enough to practice the fundamentals.

# %% [markdown]
# ## 1.1 Check input and output shapes

# %%
X.shape, y.shape
# Out:
# ((1000, 2), (1000,))

# %%
X
# Out:
# array([[ 0.75424625,  0.23148074],
#        [-0.75615888,  0.15325888],
#        [-0.81539193,  0.17328203],
#        ...,
#        [-0.13690036, -0.81001183],
#        [ 0.67036156, -0.76750154],
#        [ 0.28105665,  0.96382443]])

# %%
# View the first example of features and labels
X_sample = X[0]
y_sample = y[0]

print(f"Values for one sample of X: {X_sample} and the same for y: {y_sample}")
print(f"Shapes for one sample of X: {X_sample.shape} and the same for y: {y_sample.shape}")
# Out:
# Values for one sample of X: [0.75424625 0.23148074] and the same for y: 1
# Shapes for one sample of X: (2,) and the same for y: ()

# %% [markdown]
# ## 1.2 Turn data into tensors and create train and test splits
